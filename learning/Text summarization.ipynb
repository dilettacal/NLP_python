# %%
###SVD
# Singular-value decomposition
from numpy import array
from scipy.linalg import svd
# define a matrix
A = array([[1, 2], [3, 4], [5, 6]])
print(A)
# SVD
U, s, VT = svd(A)
print("Matrix U - Left-singular Vectors of A:")
print(U)
print("Sigma: Diagonal Matrix:")
print(s)
print("V^T: Right-singular vectors of A:")
print(VT)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# Matrix U - Left-singular Vectors of A:
# [[-0.2298477   0.88346102  0.40824829]
#  [-0.52474482  0.24078249 -0.81649658]
#  [-0.81964194 -0.40189603  0.40824829]]
# Sigma: Diagonal Matrix:
# [9.52551809 0.51430058]
# V^T: Right-singular vectors of A:
# [[-0.61962948 -0.78489445]
#  [-0.78489445  0.61962948]]

# %%
### Reconstructing 

from numpy import array
from numpy import diag
from numpy import dot
from numpy import zeros
from scipy.linalg import svd
# define a matrix
A = array([[1, 2], [3, 4], [5, 6]])
print(A)
# Singular-value decomposition
U, s, VT = svd(A)
# create m x n Sigma matrix
Sigma = zeros((A.shape[0], A.shape[1]))
# populate Sigma with n x n diagonal matrix
Sigma[:A.shape[1], :A.shape[1]] = diag(s)
# reconstruct matrix
B = U.dot(Sigma.dot(VT))
print(B)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[1. 2.]
#  [3. 4.]
#  [5. 6.]]

# %% [markdown]
# ### Document insights - Collocations

# %%
from nltk.corpus import gutenberg
import nltk
from operator import itemgetter
import re
import string
from unicodedata import normalize
from numpy import array
from nltk.corpus import stopwords

# %%
stops = set(stopwords.words('english'))

# %%
alice = gutenberg.sents(fileids="carroll-alice.txt")
alice = [' '.join(ts) for ts in alice]
alice[0]
# Out:
# "[ Alice ' s Adventures in Wonderland by Lewis Carroll 1865 ]"

# %%
def flatten_corpus(corpus):
    return ' '.join([document.strip() for document in corpus])

# %%
# clean a list of lines
def clean(corpus):
    cleaned = list()
    # prepare regex for char filtering
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for line in corpus:
        clean_pair = list()
        # normalize unicode characters
        line = normalize('NFD', line).encode('ascii', 'ignore')
        line = line.decode('UTF-8')
        # tokenize on white space
        line = line.split()
        # convert to lowercase
        line = [word.lower() for word in line if word not in stops]
        # remove punctuation from each token
        line = [word.translate(table) for word in line]
        # remove non-printable chars form each token
        line = [re_print.sub('', w) for w in line]
        # remove tokens with numbers in them
        line = [word for word in line if word.isalpha()]
        # store as string
        cleaned.append(' '.join(line))
        #cleaned.append(line)
    return cleaned

# %%
cleaned = clean(alice)

# %%
cleaned
# Out:
# ['alice adventures wonderland lewis carroll',
#  'chapter i',
#  'down rabbit hole',
#  'alice beginning get tired sitting sister bank nothing twice peeped book sister reading pictures conversations use book thought alice without pictures conversation',
#  'so considering mind well could hot day made feel sleepy stupid whether pleasure making daisy chain would worth trouble getting picking daisies suddenly white rabbit pink eyes ran close',
#  'there nothing very remarkable alice think very much way hear rabbit say oh dear',
#  'oh dear',
#  'i shall late',
#  'thought afterwards occurred ought wondered time seemed quite natural rabbit actually took a watch out of its waistcoat pocket looked hurried alice started feet flashed across mind never seen rabbit either waistcoat pocket watch take burning curiosity ran across field fortunately time see pop large rabbit hole hedge',
#  'in another moment went alice never considering world get',
#  'the rabbit hole went straight like tunnel way dipped suddenly suddenly alice moment think stopping found falling deep well',
#  'either well deep fell slowly plenty time went look wonder going happen next',
#  'first tried look make coming dark see anything looked sides well noticed filled cupboards book shelves saw maps pictures hung upon pegs',
#  'she took jar one shelves passed labelled orange marmalade great disappointment empty like drop jar fear killing somebody managed put one cupboards fell past',
#  'well',
#  'thought alice fall i shall think nothing tumbling stairs',
#  'how brave think home',
#  'why i say anything even i fell top house',
#  'which likely true',
#  'down',
#  'would fall never come end',
#  'i wonder many miles i fallen time',
#  'said aloud',
#  'i must getting somewhere near centre earth',
#  'let see would four thousand miles i think see alice learnt several things sort lessons schoolroom though very good opportunity showing knowledge one listen still good practice say yes right distance i wonder latitude longitude i got',
#  'alice idea latitude longitude either thought nice grand words say',
#  'presently began',
#  'i wonder i shall fall right through earth',
#  'how funny seem come among people walk heads downward',
#  'the antipathies i think rather glad was one listening time sound right word i shall ask name country know',
#  'please ma new zealand australia',
#  'tried curtsey spoke fancy curtseying falling air',
#  'do think could manage',
#  'and ignorant little girl think asking',
#  'no never ask perhaps i shall see written somewhere',
#  'down',
#  'there nothing else alice soon began talking',
#  'dinah miss much night i think',
#  'dinah cat',
#  'i hope remember saucer milk tea time',
#  'dinah dear',
#  'i wish',
#  'there mice air i afraid might catch bat like mouse know',
#  'but cats eat bats i wonder',
#  'and alice began get rather sleepy went saying dreamy sort way do cats eat bats',
#  'do cats eat bats',
#  'sometimes do bats eat cats',
#  'see answer either question much matter way put',
#  'she felt dozing begun dream walking hand hand dinah saying earnestly now dinah tell truth ever eat bat',
#  'suddenly thump',
#  'thump',
#  'came upon heap sticks dry leaves fall',
#  'alice bit hurt jumped feet moment looked dark overhead another long passage white rabbit still sight hurrying',
#  'there moment lost away went alice like wind time hear say turned corner oh ears whiskers late getting',
#  'she close behind turned corner rabbit longer seen found long low hall lit row lamps hanging roof',
#  'there doors round hall locked alice way one side trying every door walked sadly middle wondering ever get',
#  'suddenly came upon little three legged table made solid glass nothing except tiny golden key alice first thought might belong one doors hall alas',
#  'either locks large key small rate would open',
#  'however second time round came upon low curtain noticed behind little door fifteen inches high tried little golden key lock great delight fitted',
#  'alice opened door found led small passage much larger rat hole knelt looked along passage loveliest garden ever saw',
#  'how longed get dark hall wander among beds bright flowers cool fountains could even get head doorway even head would go thought poor alice would little use without shoulders',
#  'oh i wish i could shut like telescope',
#  'i think i could i know begin',
#  'for see many way things happened lately alice begun think things indeed really impossible',
#  'there seemed use waiting little door went back table half hoping might find another key rate book rules shutting people like telescopes time found little bottle certainly said alice round neck bottle paper label words drink me beautifully printed large letters',
#  'it well say drink wise little alice going that hurry',
#  'no i look first said see whether marked poison read several nice little histories children got burnt eaten wild beasts unpleasant things would remember simple rules friends taught red hot poker burn hold long cut finger very deeply knife usually bleeds never forgotten drink much bottle marked poison almost certain disagree sooner later',
#  'however bottle not marked poison alice ventured taste finding nice fact sort mixed flavour cherry tart custard pine apple roast turkey toffee hot buttered toast soon finished',
#  '',
#  '',
#  '',
#  'what curious feeling',
#  'said alice i must shutting like telescope',
#  'and indeed ten inches high face brightened thought right size going little door lovely garden',
#  'first however waited minutes see going shrink felt little nervous might end know said alice going altogether like candle',
#  'i wonder i like',
#  'and tried fancy flame candle like candle blown could remember ever seen thing',
#  'after finding nothing happened decided going garden alas poor alice',
#  'got door found forgotten little golden key went back table found could possibly reach could see quite plainly glass tried best climb one legs table slippery tired trying poor little thing sat cried',
#  'come use crying like',
#  'said alice rather sharply i advise leave minute',
#  'she generally gave good advice though seldom followed sometimes scolded severely bring tears eyes remembered trying box ears cheated game croquet playing curious child fond pretending two people',
#  'but use thought poor alice pretend two people',
#  'why hardly enough left make one respectable person',
#  'soon eye fell little glass box lying table opened found small cake words eat me beautifully marked currants',
#  'well i eat said alice makes grow larger i reach key makes grow smaller i creep door either way i get garden i care happens',
#  'she ate little bit said anxiously which way',
#  'which way',
#  'holding hand top head feel way growing quite surprised find remained size sure generally happens one eats cake alice got much way expecting nothing way things happen seemed quite dull stupid life go common way',
#  'so set work soon finished cake',
#  '',
#  '',
#  '',
#  'chapter ii',
#  'the pool tears',
#  'curiouser curiouser',
#  'cried alice much surprised moment quite forgot speak good english i opening like largest telescope ever',
#  'good bye feet',
#  'looked feet seemed almost sight getting far',
#  'oh poor little feet i wonder put shoes stockings dears',
#  'i sure i able',
#  'i shall great deal far trouble must manage best way i must kind thought alice perhaps walk way i want go',
#  'let see i give new pair boots every christmas',
#  'and went planning would manage',
#  'they must go carrier thought funny seem sending presents one feet',
#  'and odd directions look',
#  'alice s right foot esq',
#  'hearthrug near the fender with alice s love',
#  'oh dear nonsense i talking',
#  'just head struck roof hall fact nine feet high took little golden key hurried garden door',
#  'poor alice',
#  'it much could lying one side look garden one eye get hopeless ever sat began cry',
#  'you ought ashamed said alice great girl like might well say go crying way',
#  'stop moment i tell',
#  'but went shedding gallons tears large pool round four inches deep reaching half hall',
#  'after time heard little pattering feet distance hastily dried eyes see coming',
#  'it white rabbit returning splendidly dressed pair white kid gloves one hand large fan came trotting along great hurry muttering came oh',
#  'duchess duchess',
#  'oh',
#  'savage i kept waiting',
#  'alice felt desperate ready ask help one rabbit came near began low timid voice if please sir the rabbit started violently dropped white kid gloves fan skurried away darkness hard could go',
#  'alice took fan gloves hall hot kept fanning time went talking dear dear',
#  'how queer everything day',
#  'and yesterday things went usual',
#  'i wonder i changed night',
#  'let think i i got morning',
#  'i almost think i remember feeling little different',
#  'but i next question who world i',
#  'ah that s great puzzle',
#  'and began thinking children knew age see could changed',
#  'i sure i ada said hair goes long ringlets mine go ringlets i sure i mabel i know sorts things oh',
#  'knows little',
#  'besides she s i i oh dear puzzling',
#  'i try i know things i used know',
#  'let see four times five twelve four times six thirteen four times seven oh dear',
#  'i shall never get twenty rate',
#  'however multiplication table signify let try geography',
#  'london capital paris paris capital rome rome that s wrong i certain',
#  'i must changed mabel',
#  'i try say how doth little crossed hands lap saying lessons began repeat voice sounded hoarse strange words come used',
#  'how doth little crocodile improve shining tail and pour waters nile on every golden scale',
#  'how cheerfully seems grin how neatly spread claws and welcome little fishes with gently smiling jaws',
#  'i sure right words said poor alice eyes filled tears went i must mabel i shall go live poky little house next toys play oh',
#  'ever many lessons learn',
#  'no i made mind i mabel i stay',
#  'it use putting heads saying come dear',
#  'i shall look say who i',
#  'tell first i like person i come i stay till i somebody else oh dear',
#  'cried alice sudden burst tears i wish would put heads',
#  'i very tired alone',
#  'as said looked hands surprised see put one rabbit little white kid gloves talking',
#  'how can i done',
#  'thought',
#  'i must growing small',
#  'she got went table measure found nearly could guess two feet high going shrinking rapidly soon found cause fan holding dropped hastily time avoid shrinking away altogether',
#  'that was narrow escape',
#  'said alice good deal frightened sudden change glad find still existence garden',
#  'ran speed back little door alas',
#  'little door shut little golden key lying glass table things worse ever thought poor child i never small never',
#  'and i declare bad',
#  'as said words foot slipped another moment splash',
#  'chin salt water',
#  'her first idea somehow fallen sea case i go back railway said',
#  'alice seaside life come general conclusion wherever go english coast find number bathing machines sea children digging sand wooden spades row lodging houses behind railway station',
#  'however soon made pool tears wept nine feet high',
#  'i wish i cried much',
#  'said alice swam trying find way',
#  'i shall punished i suppose drowned tears',
#  'that will queer thing sure',
#  'however everything queer day',
#  'just heard something splashing pool little way swam nearer make first thought must walrus hippopotamus remembered small soon made mouse slipped like',
#  'would use thought alice speak mouse',
#  'everything way i think likely talk rate harm trying',
#  'so began o mouse know way pool',
#  'i tired swimming o mouse',
#  'alice thought must right way speaking mouse never done thing remembered seen brother latin grammar a mouse mouse mouse mouse o mouse',
#  'the mouse looked rather inquisitively seemed wink one little eyes said nothing',
#  'perhaps understand english thought alice i daresay french mouse come william conqueror',
#  'for knowledge history alice clear notion long ago anything happened',
#  'so began ou est chatte',
#  'first sentence french lesson book',
#  'the mouse gave sudden leap water seemed quiver fright',
#  'oh i beg pardon',
#  'cried alice hastily afraid hurt poor animal feelings',
#  'i quite forgot like cats',
#  'not like cats',
#  'cried mouse shrill passionate voice',
#  'would you like cats',
#  'well perhaps said alice soothing tone angry',
#  'and yet i wish i could show cat dinah i think take fancy cats could see',
#  'she dear quiet thing alice went half swam lazily pool sits purring nicely fire licking paws washing face nice soft thing nurse capital one catching mice oh i beg pardon',
#  'cried alice time mouse bristling felt certain must really offended',
#  'we talk rather',
#  'we indeed',
#  'cried mouse trembling end tail',
#  'as i would talk subject',
#  'our family always hated cats nasty low vulgar things',
#  'don let hear name',
#  'i indeed',
#  'said alice great hurry change subject conversation',
#  'are fond dogs',
#  'the mouse answer alice went eagerly there nice little dog near house i like show',
#  'a little bright eyed terrier know oh long curly brown hair',
#  'and fetch things throw sit beg dinner sorts things i remember half belongs farmer know says useful worth hundred pounds',
#  'he says kills rats oh dear',
#  'cried alice sorrowful tone i afraid i offended',
#  'for mouse swimming away hard could go making quite commotion pool went',
#  'so called softly mouse dear',
#  'do come back talk cats dogs either like',
#  'when mouse heard turned round swam slowly back face quite pale passion alice thought said low trembling voice let us get shore i tell history understand i hate cats dogs',
#  'it high time go pool getting quite crowded birds animals fallen duck dodo lory eaglet several curious creatures',
#  'alice led way whole party swam shore',
#  'chapter iii',
#  'a caucus race long tale',
#  'they indeed queer looking party assembled bank birds draggled feathers animals fur clinging close dripping wet cross uncomfortable',
#  'the first question course get dry consultation minutes seemed quite natural alice find talking familiarly known life',
#  'indeed quite long argument lory last turned sulky would say i older must know better alice would allow without knowing old lory positively refused tell age said',
#  'at last mouse seemed person authority among called sit listen',
#  'i ll soon make dry enough',
#  'they sat large ring mouse middle',
#  'alice kept eyes anxiously fixed felt sure would catch bad cold get dry soon',
#  'ahem',
#  'said mouse important air ready',
#  'this driest thing i know',
#  'silence round please',
#  'william conqueror whose cause favoured pope soon submitted english wanted leaders late much accustomed usurpation conquest',
#  'edwin morcar earls mercia northumbria',
#  'ugh',
#  'said lory shiver',
#  'i beg pardon',
#  'said mouse frowning politely did speak',
#  'not i',
#  'said lory hastily',
#  'i thought said mouse',
#  'i proceed',
#  'edwin morcar earls mercia northumbria declared even stigand patriotic archbishop canterbury found advisable',
#  'found what',
#  'said duck',
#  'found it mouse replied rather crossly course know means',
#  'i know means well enough i find thing said duck generally frog worm',
#  'the question archbishop find',
#  'the mouse notice question hurriedly went found advisable go edgar atheling meet william offer crown',
#  'william conduct first moderate',
#  'but insolence normans how getting dear',
#  'continued turning alice spoke',
#  'as wet ever said alice melancholy tone seem dry',
#  'in case said dodo solemnly rising feet i move meeting adjourn immediate adoption energetic remedies',
#  'speak english',
#  'said eaglet',
#  'i know meaning half long words i believe either',
#  'and eaglet bent head hide smile birds tittered audibly',
#  'what i going say said dodo offended tone best thing get us dry would caucus race',
#  'what is caucus race',
#  'said alice wanted much know dodo paused thought somebody ought speak one else seemed inclined say anything',
#  'why said dodo best way explain',
#  'and might like try thing winter day i tell dodo managed',
#  'first marked race course sort circle exact shape matter said party placed along course',
#  'there one two three away began running liked left liked easy know race',
#  'however running half hour quite dry dodo suddenly called the race',
#  'crowded round panting asking but',
#  'this question dodo could answer without great deal thought sat long time one finger pressed upon forehead position usually see shakespeare pictures rest waited silence',
#  'at last dodo said everybody must prizes',
#  'but give prizes',
#  'quite chorus voices asked',
#  'why she course said dodo pointing alice one finger whole party crowded round calling confused way prizes',
#  'prizes',
#  'alice idea despair put hand pocket pulled box comfits luckily salt water got handed round prizes',
#  'there exactly one piece round',
#  'but must prize know said mouse',
#  'of course dodo replied gravely',
#  'what else got pocket',
#  'went turning alice',
#  'only thimble said alice sadly',
#  'hand said dodo',
#  'then crowded round dodo solemnly presented thimble saying we beg acceptance elegant thimble finished short speech cheered',
#  'alice thought whole thing absurd looked grave dare laugh could think anything say simply bowed took thimble looking solemn could',
#  'the next thing eat comfits caused noise confusion large birds complained could taste small ones choked patted back',
#  'however last sat ring begged mouse tell something',
#  'you promised tell history know said alice hate c d added whisper half afraid would offended',
#  'mine long sad tale',
#  'said mouse turning alice sighing',
#  'it is long tail certainly said alice looking wonder mouse tail call sad',
#  'and kept puzzling mouse speaking idea tale something like',
#  'fury said mouse that met house let us go law i prosecute you come i take denial we must trial for really morning i nothing',
#  'said mouse cur such trial dear sir with jury judge would wasting breath',
#  'i judge i jury said cunning old fury i try whole cause condemn death',
#  'you attending',
#  'said mouse alice severely',
#  'what thinking',
#  'i beg pardon said alice humbly got fifth bend i think',
#  'i not',
#  'cried mouse sharply angrily',
#  'a knot',
#  'said alice always ready make useful looking anxiously',
#  'oh let help undo',
#  'i shall nothing sort said mouse getting walking away',
#  'you insult talking nonsense',
#  'i mean',
#  'pleaded poor alice',
#  'but easily offended know',
#  'the mouse growled reply',
#  'please come back finish story',
#  'alice called others joined chorus yes please',
#  'mouse shook head impatiently walked little quicker',
#  'what pity stay',
#  'sighed lory soon quite sight old crab took opportunity saying daughter ah dear',
#  'let lesson never lose your temper',
#  'hold tongue ma',
#  'said young crab little snappishly',
#  'you enough try patience oyster',
#  'i wish i dinah i know i',
#  'said alice aloud addressing nobody particular',
#  'she soon fetch back',
#  'and dinah i might venture ask question',
#  'said lory',
#  'alice replied eagerly always ready talk pet dinah cat',
#  'and capital one catching mice think',
#  'and oh i wish could see birds',
#  'why eat little bird soon look',
#  'this speech caused remarkable sensation among party',
#  'some birds hurried one old magpie began wrapping carefully remarking i really must getting home night air suit throat',
#  'canary called trembling voice children come away dears',
#  'it high time bed',
#  'on various pretexts moved alice soon left alone',
#  'i wish i mentioned dinah',
#  'said melancholy tone',
#  'nobody seems like i sure best cat world',
#  'oh dear dinah',
#  'i wonder i shall ever see',
#  'and poor alice began cry felt lonely low spirited',
#  'in little however heard little pattering footsteps distance looked eagerly half hoping mouse changed mind coming back finish story',
#  'chapter iv',
#  'the rabbit sends little bill',
#  'it white rabbit trotting slowly back looking anxiously went lost something heard muttering the duchess',
#  'the duchess',
#  'oh dear paws',
#  'oh fur whiskers',
#  'she get executed sure ferrets ferrets',
#  'where can i dropped i wonder',
#  'alice guessed moment looking fan pair white kid gloves good naturedly began hunting nowhere seen everything seemed changed since swim pool great hall glass table little door vanished completely',
#  'very soon rabbit noticed alice went hunting called angry tone why mary ann are',
#  'run home moment fetch pair gloves fan',
#  'quick',
#  'and alice much frightened ran direction pointed without trying explain mistake made',
#  'he took housemaid said ran',
#  'how surprised finds i',
#  'but i better take fan gloves i find',
#  'as said came upon neat little house door bright brass plate name w',
#  'rabbit engraved upon',
#  'she went without knocking hurried upstairs great fear lest meet real mary ann turned house found fan gloves',
#  'how queer seems alice said going messages rabbit',
#  'i suppose dinah sending messages next',
#  'and began fancying sort thing would happen miss alice',
#  'come directly get ready walk',
#  'coming minute nurse',
#  'but i got see mouse get',
#  'only i think alice went let dinah stop house began ordering people like',
#  'by time found way tidy little room table window hoped fan two three pairs tiny white kid gloves took fan pair gloves going leave room eye fell upon little bottle stood near looking glass',
#  'there label time words drink me nevertheless uncorked put lips',
#  'i know something interesting sure happen said whenever i eat drink anything i see bottle',
#  'i hope make grow large really i quite tired tiny little thing',
#  'it indeed much sooner expected drunk half bottle found head pressing ceiling stoop save neck broken',
#  'she hastily put bottle saying that quite enough i hope i grow as i get door i wish i drunk quite much',
#  'alas',
#  'late wish',
#  'she went growing growing soon kneel floor another minute even room tried effect lying one elbow door arm curled round head',
#  'still went growing last resource put one arm window one foot chimney said now i whatever happens',
#  'what will become',
#  'luckily alice little magic bottle full effect grew larger still uncomfortable seemed sort chance ever getting room wonder felt unhappy',
#  'it much pleasanter home thought poor alice one always growing larger smaller ordered mice rabbits',
#  'i almost wish i gone rabbit hole yet yet rather curious know sort life',
#  'i wonder can happened',
#  'when i used read fairy tales i fancied kind thing never happened i middle one',
#  'there ought book written ought',
#  'and i grow i write one i grown added sorrowful tone least room grow here',
#  'but thought alice shall i never get older i',
#  'that comfort one way never old woman always lessons learn',
#  'oh i like that',
#  'oh foolish alice',
#  'answered',
#  'how learn lessons',
#  'why hardly room you room lesson books',
#  'and went taking first one side making quite conversation altogether minutes heard voice outside stopped listen',
#  'mary ann',
#  'mary ann',
#  'said voice',
#  'fetch gloves moment',
#  'then came little pattering feet stairs',
#  'alice knew rabbit coming look trembled till shook house quite forgetting thousand times large rabbit reason afraid',
#  'presently rabbit came door tried open door opened inwards alice elbow pressed hard attempt proved failure',
#  'alice heard say then i go round get window',
#  'that thought alice waiting till fancied heard rabbit window suddenly spread hand made snatch air',
#  'she get hold anything heard little shriek fall crash broken glass concluded possible fallen cucumber frame something sort',
#  'next came angry voice rabbit pat',
#  'pat',
#  'where',
#  'and voice never heard sure i',
#  'digging apples yer honour',
#  'digging apples indeed',
#  'said rabbit angrily',
#  'here',
#  'come help this',
#  'sounds broken glass',
#  'now tell pat window',
#  'sure arm yer honour',
#  'he pronounced arrum',
#  'an arm goose',
#  'who ever saw one size',
#  'why fills whole window',
#  'sure yer honour arm',
#  'well got business rate go take away',
#  'there long silence alice could hear whispers sure i like yer honour',
#  'do i tell coward',
#  'last spread hand made another snatch air',
#  'this time two little shrieks sounds broken glass',
#  'what number cucumber frames must',
#  'thought alice',
#  'i wonder next',
#  'as pulling window i wish could',
#  'i sure i want stay longer',
#  'she waited time without hearing anything last came rumbling little cartwheels sound good many voices talking together made words where ladder why i bring one bill got bill',
#  'fetch lad here put em corner no tie em together first reach half high enough yet oh',
#  'well enough particular here bill',
#  'catch hold rope will roof bear mind loose slate oh coming',
#  'heads',
#  'loud crash now it bill i fancy who go chimney nay i',
#  'you that i bill go here bill',
#  'master says go chimney',
#  'oh',
#  'so bill got come chimney',
#  'said alice',
#  'shy seem put everything upon bill',
#  'i bill place good deal fireplace narrow sure i think i kick little',
#  'she drew foot far chimney could waited till heard little animal guess sort scratching scrambling chimney close saying this bill gave one sharp kick waited see would happen next',
#  'the first thing heard general chorus there goes bill',
#  'rabbit voice along catch hedge',
#  'silence another confusion voices hold head brandy don choke how old fellow',
#  'what happened',
#  'tell us',
#  'last came little feeble squeaking voice that bill thought alice well i hardly know no thank ye i better i deal flustered tell i know something comes like jack box i goes like sky rocket',
#  'so old fellow',
#  'said others',
#  'we must burn house',
#  'said rabbit voice alice called loud could if',
#  'i set dinah',
#  'there dead silence instantly alice thought i wonder will next',
#  'if sense take roof',
#  'after minute two began moving alice heard rabbit say a barrowful begin',
#  'a barrowful what',
#  'thought alice long doubt next moment shower little pebbles came rattling window hit face',
#  'i put stop said shouted you better',
#  'produced another dead silence',
#  'alice noticed surprise pebbles turning little cakes lay floor bright idea came head',
#  'if i eat one cakes thought sure make some change size possibly make larger must make smaller i suppose',
#  'so swallowed one cakes delighted find began shrinking directly',
#  'as soon small enough get door ran house found quite crowd little animals birds waiting outside',
#  'the poor little lizard bill middle held two guinea pigs giving something bottle',
#  'they made rush alice moment appeared ran hard could soon found safe thick wood',
#  'the first thing i got said alice wandered wood grow right size second thing find way lovely garden',
#  'i think best plan',
#  'it sounded excellent plan doubt neatly simply arranged difficulty smallest idea set peering anxiously among trees little sharp bark head made look great hurry',
#  'an enormous puppy looking large round eyes feebly stretching one paw trying touch',
#  'poor little thing',
#  'said alice coaxing tone tried hard whistle terribly frightened time thought might hungry case would likely eat spite coaxing',
#  'hardly knowing picked little bit stick held puppy whereupon puppy jumped air feet yelp delight rushed stick made believe worry alice dodged behind great thistle keep run moment appeared side puppy made another rush stick tumbled head heels hurry get hold alice thinking like game play cart horse expecting every moment trampled feet ran round thistle puppy began series short charges stick running little way forwards time long way back barking hoarsely till last sat good way panting tongue hanging mouth great eyes half shut',
#  'this seemed alice good opportunity making escape set ran till quite tired breath till puppy bark sounded quite faint distance',
#  'and yet dear little puppy',
#  'said alice leant buttercup rest fanned one leaves i liked teaching tricks much i right size',
#  'oh dear',
#  'i nearly forgotten i got grow',
#  'let see is managed',
#  'i suppose i ought eat drink something great question',
#  'the great question certainly',
#  'alice looked round flowers blades grass see anything looked like right thing eat drink circumstances',
#  'there large mushroom growing near height looked sides behind occurred might well look see top',
#  'she stretched tiptoe peeped edge mushroom eyes immediately met large caterpillar sitting top arms folded quietly smoking long hookah taking smallest notice anything else',
#  'chapter v advice caterpillar',
#  'the caterpillar alice looked time silence last caterpillar took hookah mouth addressed languid sleepy voice',
#  'who you',
#  'said caterpillar',
#  'this encouraging opening conversation',
#  'alice replied rather shyly i i hardly know sir present least i know i was i got morning i think i must changed several times since',
#  'what mean',
#  'said caterpillar sternly',
#  'explain',
#  'i explain myself i afraid sir said alice i see',
#  'i see said caterpillar',
#  'i afraid i put clearly alice replied politely i understand begin many different sizes day confusing',
#  'it said caterpillar',
#  'well perhaps found yet said alice turn chrysalis day know butterfly i think feel little queer',
#  'not bit said caterpillar',
#  'well perhaps feelings may different said alice i know would feel queer me',
#  'you',
#  'said caterpillar contemptuously',
#  'who you',
#  'which brought back beginning conversation',
#  'alice felt little irritated caterpillar making very short remarks drew said gravely i think ought tell you first',
#  'why',
#  'said caterpillar',
#  'here another puzzling question alice could think good reason caterpillar seemed very unpleasant state mind turned away',
#  'come back',
#  'caterpillar called',
#  'i something important say',
#  'this sounded promising certainly alice turned came back',
#  'keep temper said caterpillar',
#  'is',
#  'said alice swallowing anger well could',
#  'no said caterpillar',
#  'alice thought might well wait nothing else perhaps might tell something worth hearing',
#  'for minutes puffed away without speaking last unfolded arms took hookah mouth said so think changed',
#  'i afraid i sir said alice i remember things i used i keep size ten minutes together',
#  'can remember what things',
#  'said caterpillar',
#  'well i tried say how doth the little busy bee came different',
#  'alice replied melancholy voice',
#  'repeat you are old father william said caterpillar',
#  'alice folded hands began',
#  'you old father william young man said and hair become white and yet incessantly stand head do think age right',
#  'in youth father william replied son i feared might injure brain but i perfectly sure i none why i',
#  'you old said youth i mentioned and grown uncommonly fat yet turned back somersault door pray reason',
#  'in youth said sage shook grey locks i kept limbs supple by use ointment one shilling box allow sell couple',
#  'you old said youth jaws weak for anything tougher suet yet finished goose bones beak pray manage',
#  'in youth said father i took law and argued case wife and muscular strength gave jaw has lasted rest life',
#  'you old said youth one would hardly suppose that eye steady ever yet balanced eel end nose what made awfully clever',
#  'i answered three questions enough said father give airs',
#  'do think i listen day stuff',
#  'be i kick stairs',
#  'that said right said caterpillar',
#  'not quite right i afraid said alice timidly words got altered',
#  'it wrong beginning end said caterpillar decidedly silence minutes',
#  'the caterpillar first speak',
#  'what size want',
#  'asked',
#  'oh i particular size alice hastily replied one like changing often know',
#  'i don t know said caterpillar',
#  'alice said nothing never much contradicted life felt losing temper',
#  'are content',
#  'said caterpillar',
#  'well i like little larger sir mind said alice three inches wretched height',
#  'it good height indeed',
#  'said caterpillar angrily rearing upright spoke exactly three inches high',
#  'but i used',
#  'pleaded poor alice piteous tone',
#  'and thought i wish creatures easily offended',
#  'you get used time said caterpillar put hookah mouth began smoking',
#  'this time alice waited patiently chose speak',
#  'in minute two caterpillar took hookah mouth yawned twice shook',
#  'then got mushroom crawled away grass merely remarking went one side make grow taller side make grow shorter',
#  'one side what',
#  'the side what',
#  'thought alice',
#  'of mushroom said caterpillar asked aloud another moment sight',
#  'alice remained looking thoughtfully mushroom minute trying make two sides perfectly round found difficult question',
#  'however last stretched arms round far would go broke bit edge hand',
#  'and',
#  'said nibbled little right hand bit try effect next moment felt violent blow underneath chin struck foot',
#  'she good deal frightened sudden change felt time lost shrinking rapidly set work eat bit',
#  'her chin pressed closely foot hardly room open mouth last managed swallow morsel lefthand bit',
#  '',
#  '',
#  '',
#  'come head free last',
#  'said alice tone delight changed alarm another moment found shoulders nowhere found could see looked immense length neck seemed rise like stalk sea green leaves lay far',
#  'what can green stuff',
#  'said alice',
#  'and have shoulders got',
#  'and oh poor hands i see',
#  'she moving spoke result seemed follow except little shaking among distant green leaves',
#  'as seemed chance getting hands head tried get head delighted find neck would bend easily direction like serpent',
#  'she succeeded curving graceful zigzag going dive among leaves found nothing tops trees wandering sharp hiss made draw back hurry large pigeon flown face beating violently wings',
#  'serpent',
#  'screamed pigeon',
#  'i not serpent',
#  'said alice indignantly',
#  'let alone',
#  'serpent i say',
#  'repeated pigeon subdued tone added kind sob i tried every way nothing seems suit',
#  'i least idea talking said alice',
#  'i tried roots trees i tried banks i tried hedges pigeon went without attending serpents',
#  'there pleasing',
#  'alice puzzled thought use saying anything till pigeon finished',
#  'as trouble enough hatching eggs said pigeon i must look serpents night day',
#  'why i wink sleep three weeks',
#  'i sorry annoyed said alice beginning see meaning',
#  'and i taken highest tree wood continued pigeon raising voice shriek i thinking i free last must needs come wriggling sky',
#  'ugh serpent',
#  'but i not serpent i tell',
#  'said alice',
#  'i i',
#  'well',
#  'what',
#  'said pigeon',
#  'i see trying invent something',
#  'i i little girl said alice rather doubtfully remembered number changes gone day',
#  'a likely story indeed',
#  'said pigeon tone deepest contempt',
#  'i seen good many little girls time never one neck',
#  'no',
#  'you serpent use denying',
#  'i suppose telling next never tasted egg',
#  'i have tasted eggs certainly said alice truthful child little girls eat eggs quite much serpents know',
#  'i believe said pigeon kind serpent i say',
#  'this new idea alice quite silent minute two gave pigeon opportunity adding you looking eggs i know that well enough matter whether little girl serpent',
#  'it matters good deal me said alice hastily i looking eggs happens i i want yours i like raw',
#  'well',
#  'said pigeon sulky tone settled nest',
#  'alice crouched among trees well could neck kept getting entangled among branches every stop untwist',
#  'after remembered still held pieces mushroom hands set work carefully nibbling first one growing sometimes taller sometimes shorter succeeded bringing usual height',
#  'it long since anything near right size felt quite strange first got used minutes began talking usual',
#  'come half plan done',
#  'how puzzling changes',
#  'i never sure i going one minute another',
#  'however i got back right size next thing get beautiful garden is done i wonder',
#  'as said came suddenly upon open place little house four feet high',
#  'whoever lives thought alice never come upon this size i frighten wits',
#  'so began nibbling righthand bit venture go near house till brought nine inches high',
#  'chapter vi',
#  'pig pepper',
#  'for minute two stood looking house wondering next suddenly footman livery came running wood considered footman livery otherwise judging face would called fish rapped loudly door knuckles',
#  'it opened another footman livery round face large eyes like frog footmen alice noticed powdered hair curled heads',
#  'she felt curious know crept little way wood listen',
#  'the fish footman began producing arm great letter nearly large handed saying solemn tone for duchess',
#  'an invitation queen play croquet',
#  'the frog footman repeated solemn tone changing order words little from queen',
#  'an invitation duchess play croquet',
#  'then bowed low curls got entangled together',
#  'alice laughed much run back wood fear hearing next peeped fish footman gone sitting ground near door staring stupidly sky',
#  'alice went timidly door knocked',
#  'there sort use knocking said footman two reasons',
#  'first i side door secondly making noise inside one could possibly hear',
#  'and certainly extraordinary noise going within constant howling sneezing every great crash dish kettle broken pieces',
#  'please said alice i get',
#  'there might sense knocking footman went without attending door us',
#  'for instance inside might knock i could let know',
#  'he looking sky time speaking alice thought decidedly uncivil',
#  'but perhaps help said eyes very nearly top head',
#  'but rate might answer questions how i get',
#  'repeated aloud',
#  'i shall sit footman remarked till tomorrow',
#  'at moment door house opened large plate came skimming straight footman head grazed nose broke pieces one trees behind',
#  'next day maybe footman continued tone exactly nothing happened',
#  'how i get',
#  'asked alice louder tone',
#  'are get',
#  'said footman',
#  'that first question know',
#  'it doubt alice like told',
#  'it really dreadful muttered way creatures argue',
#  'it enough drive one crazy',
#  'the footman seemed think good opportunity repeating remark variations',
#  'i shall sit said days days',
#  'but i',
#  'said alice',
#  'anything like said footman began whistling',
#  'oh use talking said alice desperately perfectly idiotic',
#  'and opened door went',
#  'the door led right large kitchen full smoke one end duchess sitting three legged stool middle nursing baby cook leaning fire stirring large cauldron seemed full soup',
#  'there certainly much pepper soup',
#  'alice said well could sneezing',
#  'there certainly much air',
#  'even duchess sneezed occasionally baby sneezing howling alternately without moment pause',
#  'the things kitchen sneeze cook large cat sitting hearth grinning ear ear',
#  'please would tell said alice little timidly quite sure whether good manners speak first cat grins like',
#  'it cheshire cat said duchess',
#  'pig',
#  'she said last word sudden violence alice quite jumped saw another moment addressed baby took courage went',
#  'i know cheshire cats always grinned fact i know cats could grin',
#  'they said duchess em',
#  'i know alice said politely feeling quite pleased got conversation',
#  'you know much said duchess fact',
#  'alice like tone remark thought would well introduce subject conversation',
#  'while trying fix one cook took cauldron soup fire set work throwing everything within reach duchess baby fire irons came first followed shower saucepans plates dishes',
#  'the duchess took notice even hit baby howling much already quite impossible say whether blows hurt',
#  'oh please mind',
#  'cried alice jumping agony terror',
#  'oh goes precious nose unusually large saucepan flew close nearly carried',
#  'if everybody minded business duchess said hoarse growl world would go round deal faster',
#  'which would not advantage said alice felt glad get opportunity showing little knowledge',
#  'just think work would make day night',
#  'you see earth takes twenty four hours turn round axis',
#  'talking axes said duchess chop head',
#  'alice glanced rather anxiously cook see meant take hint cook busily stirring soup seemed listening went twenty four hours i think twelve',
#  'i',
#  'oh bother me said duchess i never could abide figures',
#  'and began nursing child singing sort lullaby giving violent shake end every line',
#  'speak roughly little boy and beat sneezes he annoy because knows teases',
#  'chorus',
#  'in cook baby joined',
#  'wow',
#  'wow',
#  'wow',
#  'while duchess sang second verse song kept tossing baby violently poor little thing howled alice could hardly hear words',
#  'i speak severely boy i beat sneezes for thoroughly enjoy the pepper pleases',
#  'chorus',
#  'wow',
#  'wow',
#  'wow',
#  'here',
#  'may nurse bit like',
#  'duchess said alice flinging baby spoke',
#  'i must go get ready play croquet queen hurried room',
#  'the cook threw frying pan went missed',
#  'alice caught baby difficulty queer shaped little creature held arms legs directions like star fish thought alice',
#  'the poor little thing snorting like steam engine caught kept doubling straightening altogether first minute two much could hold',
#  'as soon made proper way nursing twist sort knot keep tight hold right ear left foot prevent undoing carried open air',
#  'if i take child away thought alice sure kill day two murder leave behind',
#  'she said last words loud little thing grunted reply left sneezing time',
#  'don grunt said alice proper way expressing',
#  'the baby grunted alice looked anxiously face see matter',
#  'there could doubt very turn nose much like snout real nose also eyes getting extremely small baby altogether alice like look thing',
#  'but perhaps sobbing thought looked eyes see tears',
#  'no tears',
#  'if going turn pig dear said alice seriously i nothing',
#  'mind',
#  'the poor little thing sobbed grunted impossible say went silence',
#  'alice beginning think now i creature i get home',
#  'grunted violently looked face alarm',
#  'this time could no mistake neither less pig felt would quite absurd carry',
#  'so set little creature felt quite relieved see trot away quietly wood',
#  'if grown said would made dreadfully ugly child makes rather handsome pig i think',
#  'and began thinking children knew might well pigs saying one knew right way change little startled seeing cheshire cat sitting bough tree yards',
#  'the cat grinned saw alice',
#  'it looked good natured thought still very long claws great many teeth felt ought treated respect',
#  'cheshire puss began rather timidly know whether would like name however grinned little wider',
#  'come pleased far thought alice went',
#  'would tell please way i ought go',
#  'that depends good deal want get said cat',
#  'i much care said alice',
#  'then matter way go said cat',
#  'long i get somewhere alice added explanation',
#  'oh sure said cat walk long enough',
#  'alice felt could denied tried another question',
#  'what sort people live',
#  'in that direction cat said waving right paw round lives hatter that direction waving paw lives march hare',
#  'visit either like mad',
#  'but i want go among mad people alice remarked',
#  'oh help said cat mad',
#  'i mad',
#  'you mad',
#  'how know i mad',
#  'said alice',
#  'you must said cat come',
#  'alice think proved however went and know mad',
#  'to begin said cat dog mad',
#  'you grant',
#  'i suppose said alice',
#  'well cat went see dog growls angry wags tail pleased',
#  'now i growl i pleased wag tail i angry',
#  'therefore i mad',
#  'i call purring growling said alice',
#  'call like said cat',
#  'do play croquet queen day',
#  'i like much said alice i invited yet',
#  'you see said cat vanished',
#  'alice much surprised getting used queer things happening',
#  'while looking place suddenly appeared',
#  'by bye became baby',
#  'said cat',
#  'i nearly forgotten ask',
#  'it turned pig alice quietly said come back natural way',
#  'i thought would said cat vanished',
#  'alice waited little half expecting see appear minute two walked direction march hare said live',
#  'i seen hatters said march hare much interesting perhaps may raving mad least mad march',
#  'as said looked cat sitting branch tree',
#  'did say pig fig',
#  'said cat',
#  'i said pig replied alice i wish keep appearing vanishing suddenly make one quite giddy',
#  'all right said cat time vanished quite slowly beginning end tail ending grin remained time rest gone',
#  'well',
#  'i often seen cat without grin thought alice grin without cat',
#  'it curious thing i ever saw life',
#  'she gone much farther came sight house march hare thought must right house chimneys shaped like ears roof thatched fur',
#  'it large house like go nearer till nibbled lefthand bit mushroom raised two feet high even walked towards rather timidly saying suppose raving mad',
#  'i almost wish i gone see hatter instead',
#  'chapter vii',
#  'a mad tea party',
#  'there table set tree front house march hare hatter tea dormouse sitting fast asleep two using cushion resting elbows talking head',
#  'very uncomfortable dormouse thought alice asleep i suppose mind',
#  'the table large one three crowded together one corner no room',
#  'no room',
#  'cried saw alice coming',
#  'there plenty room',
#  'said alice indignantly sat large arm chair one end table',
#  'have wine march hare said encouraging tone',
#  'alice looked round table nothing tea',
#  'i see wine remarked',
#  'there said march hare',
#  'then civil offer said alice angrily',
#  'it civil sit without invited said march hare',
#  'i know your table said alice laid great many three',
#  'your hair wants cutting said hatter',
#  'he looking alice time great curiosity first speech',
#  'you learn make personal remarks alice said severity rude',
#  'the hatter opened eyes wide hearing said why raven like writing desk',
#  'come shall fun',
#  'thought alice',
#  'i glad begun asking riddles i believe i guess added aloud',
#  'do mean think find answer',
#  'said march hare',
#  'exactly said alice',
#  'then say mean march hare went',
#  'i alice hastily replied least least i mean i say thing know',
#  'not thing bit',
#  'said hatter',
#  'you might well say i see i eat thing i eat i see',
#  'you might well say added march hare i like i get thing i get i like',
#  'you might well say added dormouse seemed talking sleep i breathe i sleep thing i sleep i breathe',
#  'it is thing said hatter conversation dropped party sat silent minute alice thought could remember ravens writing desks much',
#  'the hatter first break silence',
#  'what day month',
#  'said turning alice taken watch pocket looking uneasily shaking every holding ear',
#  'alice considered little said the fourth',
#  'two days wrong',
#  'sighed hatter',
#  'i told butter suit works',
#  'added looking angrily march hare',
#  'it best butter march hare meekly replied',
#  'yes crumbs must got well hatter grumbled put bread knife',
#  'the march hare took watch looked gloomily dipped cup tea looked could think nothing better say first remark it best butter know',
#  'alice looking shoulder curiosity',
#  'what funny watch',
#  'remarked',
#  'it tells day month tell clock',
#  'why',
#  'muttered hatter',
#  'does your watch tell year',
#  'of course alice replied readily stays year long time together',
#  'which case mine said hatter',
#  'alice felt dreadfully puzzled',
#  'the hatter remark seemed sort meaning yet certainly english',
#  'i quite understand said politely could',
#  'the dormouse asleep said hatter poured little hot tea upon nose',
#  'the dormouse shook head impatiently said without opening eyes of course course i going remark',
#  'have guessed riddle yet',
#  'hatter said turning alice',
#  'no i give alice replied answer',
#  'i slightest idea said hatter',
#  'nor i said march hare',
#  'alice sighed wearily',
#  'i think might something better time said waste asking riddles answers',
#  'if knew time well i said hatter talk wasting it',
#  'it him',
#  'i know mean said alice',
#  'of course',
#  'hatter said tossing head contemptuously',
#  'i dare say never even spoke time',
#  'perhaps alice cautiously replied i know i beat time i learn music',
#  'ah',
#  'accounts said hatter',
#  'he stand beating',
#  'now kept good terms almost anything liked clock',
#  'for instance suppose nine clock morning time begin lessons whisper hint time round goes clock twinkling',
#  'half past one time dinner',
#  'i wish march hare said whisper',
#  'that would grand certainly said alice thoughtfully i hungry know',
#  'not first perhaps said hatter could keep half past one long liked',
#  'is way you manage',
#  'alice asked',
#  'the hatter shook head mournfully',
#  'not i',
#  'replied',
#  'we quarrelled last march he went mad know pointing tea spoon march hare great concert given queen hearts i sing',
#  'twinkle twinkle little bat',
#  'how i wonder',
#  'you know song perhaps',
#  'i heard something like said alice',
#  'it goes know hatter continued way',
#  'up world fly like tea tray sky',
#  'twinkle twinkle',
#  'here dormouse shook began singing sleep twinkle twinkle twinkle twinkle went long pinch make stop',
#  'well i hardly finished first verse said hatter queen jumped bawled he murdering time',
#  'off head',
#  'how dreadfully savage',
#  'exclaimed alice',
#  'and ever since hatter went mournful tone thing i ask',
#  'it always six clock',
#  'a bright idea came alice head',
#  'is reason many tea things put',
#  'asked',
#  'yes said hatter sigh always tea time time wash things whiles',
#  'then keep moving round i suppose',
#  'said alice',
#  'exactly said hatter things get used',
#  'but happens come beginning',
#  'alice ventured ask',
#  'suppose change subject march hare interrupted yawning',
#  'i getting tired',
#  'i vote young lady tells us story',
#  'i afraid i know one said alice rather alarmed proposal',
#  'then dormouse shall',
#  'cried',
#  'wake dormouse',
#  'and pinched sides',
#  'the dormouse slowly opened eyes',
#  'i asleep said hoarse feeble voice i heard every word fellows saying',
#  'tell us story',
#  'said march hare',
#  'yes please',
#  'pleaded alice',
#  'and quick added hatter asleep done',
#  'once upon time three little sisters dormouse began great hurry names elsie lacie tillie lived bottom well',
#  'what live',
#  'said alice always took great interest questions eating drinking',
#  'they lived treacle said dormouse thinking minute two',
#  'they done know alice gently remarked ill',
#  'so said dormouse very ill',
#  'alice tried fancy extraordinary ways living would like puzzled much went but live bottom well',
#  'take tea march hare said alice earnestly',
#  'i nothing yet alice replied offended tone i take',
#  'you mean take less said hatter easy take more nothing',
#  'nobody asked your opinion said alice',
#  'who making personal remarks',
#  'hatter asked triumphantly',
#  'alice quite know say helped tea bread butter turned dormouse repeated question',
#  'why live bottom well',
#  'the dormouse took minute two think said it treacle well',
#  'there thing',
#  'alice beginning angrily hatter march hare went sh',
#  'sh',
#  'dormouse sulkily remarked if civil better finish story',
#  'no please go',
#  'alice said humbly i interrupt',
#  'i dare say may one',
#  'one indeed',
#  'said dormouse indignantly',
#  'however consented go',
#  'and three little sisters learning draw know',
#  'what draw',
#  'said alice quite forgetting promise',
#  'treacle said dormouse without considering time',
#  'i want clean cup interrupted hatter let move one place',
#  'he moved spoke dormouse followed march hare moved dormouse place alice rather unwillingly took place march hare',
#  'the hatter one got advantage change alice good deal worse march hare upset milk jug plate',
#  'alice wish offend dormouse began cautiously but i understand',
#  'where draw treacle',
#  'you draw water water well said hatter i think could draw treacle treacle well eh stupid',
#  'but in well alice said dormouse choosing notice last remark',
#  'of course said dormouse well',
#  'this answer confused poor alice let dormouse go time without interrupting',
#  'they learning draw dormouse went yawning rubbing eyes getting sleepy drew manner things everything begins m',
#  'why m',
#  'said alice',
#  'why',
#  'said march hare',
#  'alice silent',
#  'the dormouse closed eyes time going doze pinched hatter woke little shriek went begins m mouse traps moon memory muchness know say things much muchness ever see thing drawing muchness',
#  'really ask said alice much confused i think',
#  'then talk said hatter',
#  'this piece rudeness alice could bear got great disgust walked dormouse fell asleep instantly neither others took least notice going though looked back twice half hoping would call last time saw trying put dormouse teapot',
#  'at rate i never go there',
#  'said alice picked way wood',
#  'it stupidest tea party i ever life',
#  'just said noticed one trees door leading right',
#  'that curious',
#  'thought',
#  'but everything curious today',
#  'i think i may well go',
#  'and went',
#  'once found long hall close little glass table',
#  'now i manage better time said began taking little golden key unlocking door led garden',
#  'then went work nibbling mushroom kept piece pocket till foot high walked little passage then found last beautiful garden among bright flower beds cool fountains',
#  'chapter viii',
#  'the queen croquet ground',
#  'a large rose tree stood near entrance garden roses growing white three gardeners busily painting red',
#  'alice thought curious thing went nearer watch came heard one say look five',
#  'don go splashing paint like',
#  'i help said five sulky tone seven jogged elbow',
#  'on seven looked said that right five',
#  'always lay blame others',
#  'you d better talk',
#  'said five',
#  'i heard queen say yesterday deserved beheaded',
#  'what',
#  'said one spoken first',
#  'that none your business two',
#  'said seven',
#  'yes is business',
#  'said five i tell bringing cook tulip roots instead onions',
#  'seven flung brush begun well unjust things eye chanced fall upon alice stood watching checked suddenly others looked round also bowed low',
#  'would tell said alice little timidly painting roses',
#  'five seven said nothing looked two',
#  'two began low voice why fact see miss ought red rose tree put white one mistake queen find heads cut know',
#  'so see miss best afore comes at moment five anxiously looking across garden called the queen',
#  'the queen',
#  'three gardeners instantly threw flat upon faces',
#  'there sound many footsteps alice looked round eager see queen',
#  'first came ten soldiers carrying clubs shaped like three gardeners oblong flat hands feet corners next ten courtiers ornamented diamonds walked two two soldiers',
#  'after came royal children ten little dears came jumping merrily along hand hand couples ornamented hearts',
#  'next came guests mostly kings queens among alice recognised white rabbit talking hurried nervous manner smiling everything said went without noticing',
#  'then followed knave hearts carrying king crown crimson velvet cushion last grand procession came the king and queen of hearts',
#  'alice rather doubtful whether ought lie face like three gardeners could remember ever heard rule processions besides would use procession thought people lie upon faces see',
#  'so stood still waited',
#  'when procession came opposite alice stopped looked queen said severely who',
#  'she said knave hearts bowed smiled reply',
#  'idiot',
#  'said queen tossing head impatiently turning alice went what name child',
#  'my name alice please majesty said alice politely added why pack cards',
#  'i afraid',
#  'and these',
#  'said queen pointing three gardeners lying round rosetree see lying faces pattern backs rest pack could tell whether gardeners soldiers courtiers three children',
#  ...]

# %%
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import BigramAssocMeasures

# %%
finder = BigramCollocationFinder.from_documents([item.split() for item in cleaned])

# %%
bigram_measures = BigramAssocMeasures()

# %%
#raw freqs
finder.nbest(bigram_measures.raw_freq, 10)
# Out:
# [('said', 'alice'),
#  ('mock', 'turtle'),
#  ('march', 'hare'),
#  ('said', 'king'),
#  ('i', 'think'),
#  ('thought', 'alice'),
#  ('i', 'know'),
#  ('said', 'hatter'),
#  ('white', 'rabbit'),
#  ('said', 'mock')]

# %%
#pointwise mutual information
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('abide', 'figures'),
#  ('acceptance', 'elegant'),
#  ('accounting', 'tastes'),
#  ('accustomed', 'usurpation'),
#  ('act', 'crawling'),
#  ('adjourn', 'immediate'),
#  ('adoption', 'energetic'),
#  ('agony', 'terror'),
#  ('alarmed', 'proposal'),
#  ('ambition', 'distraction')]

# %%
#trigrams 
from nltk.collocations import TrigramCollocationFinder
from nltk.collocations import TrigramAssocMeasures

finder = TrigramCollocationFinder.from_documents([item.split() for item in cleaned])

# %%
trigram_measures = TrigramAssocMeasures()

# %%
finder.nbest(trigram_measures.raw_freq, 10)
# Out:
# [('said', 'mock', 'turtle'),
#  ('said', 'march', 'hare'),
#  ('said', 'alice', 'i'),
#  ('i', 'beg', 'pardon'),
#  ('i', 'wish', 'i'),
#  ('poor', 'little', 'thing'),
#  ('i', 'think', 'i'),
#  ('little', 'golden', 'key'),
#  ('march', 'hare', 'said'),
#  ('mock', 'turtle', 'said')]

# %%
finder.nbest(trigram_measures.pmi, 10)
# Out:
# [('accustomed', 'usurpation', 'conquest'),
#  ('adjourn', 'immediate', 'adoption'),
#  ('adoption', 'energetic', 'remedies'),
#  ('ancient', 'modern', 'seaography'),
#  ('apple', 'roast', 'turkey'),
#  ('arithmetic', 'ambition', 'distraction'),
#  ('brother', 'latin', 'grammar'),
#  ('canvas', 'bag', 'tied'),
#  ('cherry', 'tart', 'custard'),
#  ('circle', 'exact', 'shape')]
